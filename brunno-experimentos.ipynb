# %%
# %load_ext autoreload
# %autoreload 5
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import random

from model import Model
import data

# %%
random.seed(47)
RANDOM_NUM = 47
np.random.seed(47)

# %%
df_base = data.CancerMama.get_data()
df_validacao = data.CancerMama.get_new_data()

X_train, X_test, y_train, y_test = train_test_split(
    df_base.iloc[:, 1:-1], df_base.iloc[:, -1], test_size=0.2, random_state=RANDOM_NUM
)

# %%
model_result = Model.fit_and_predict(X_train,X_test,y_train,y_test)
Model.plot_results(model_result, X_test, y_test)
# Out:
# Model: MLP
#             Valor
# Accuracy   0.9143
# F1         0.9112
# Precision  0.9075
# Recall     0.9166
#
# [[77  8]
#  [ 4 51]]
#
#               precision    recall  f1-score     support
# benign         0.950617  0.905882  0.927711   85.000000
# malignant      0.864407  0.927273  0.894737   55.000000
# accuracy       0.914286  0.914286  0.914286    0.914286
# macro avg      0.907512  0.916578  0.911224  140.000000
# weighted avg   0.916749  0.914286  0.914757  140.000000
# &lt;Figure size 432x288 with 2 Axes&gt;
# --------------------------------------------
